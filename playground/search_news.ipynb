# %% [markdown]
# # News MCP Search Playground
#
# Use `list_sources` and `search_news` against the local database.
#
# Before running these cells, make sure you have migrated and synced feeds into the database.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if not (repo_root / "src").exists():
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

repo_root
# Out:
# PosixPath('/Users/jackson/Codes/self/JarvisTradingLabs/open-news-mcp')

# %%
import asyncio
import json

from src.tools.search import search_news
from src.tools.sources import list_sources

# %%
async def run_list_sources(**kwargs):
    raw = await list_sources(**kwargs)
    return json.loads(raw)


async def run_search(**kwargs):
    raw = await search_news(**kwargs)
    data = json.loads(raw)
    if not data.get("ok"):
        return data

    return {
        "ok": True,
        "count": data.get("count"),
        "articles": [
            {
                "name": article.get("name"),
                "title": article.get("title"),
                "tier": article.get("tier"),
                "category": article.get("category"),
                "published_at": article.get("published_at"),
                "url": article.get("url"),
            }
            for article in data.get("articles", [])
        ],
    }


async def demo():
    return {
        "sources": await run_list_sources(tiers=[1], limit=10),
        "news": await run_search(sources=["Federal Reserve"], timespan="30d", limit=5),
    }


await demo()
# Out:
# {'sources': {'ok': True,
#   'count': 10,
#   'sources': [{'name': 'Federal Reserve',
#     'category': 'centralbanks',
#     'tier': 1,
#     'lang': None,
#     'tags': ['rates', 'liquidity', 'fed'],
#     'feed_url': 'https://www.federalreserve.gov/feeds/press_all.xml'},
#    {'name': 'Bloomberg Commodities',
#     'category': 'commodity-news',
#     'tier': 1,
#     'lang': None,
#     'tags': ['commodities', 'wire'],
#     'feed_url': 'https://news.google.com/rss/search?q=site:bloomberg.com+commodities+OR+metals+OR+mining+when:1d&hl=en-US&gl=US&ceid=US:en'},
#    {'name': 'Reuters Commodities',
#     'category': 'commodity-news',
#     'tier': 1,
#     'lang': None,
#     'tags': ['commodities', 'wire'],
#     'feed_url': 'https://news.google.com/rss/search?q=site:reuters.com+commodities+OR+metals+OR+mining+when:1d&hl=en-US&gl=US&ceid=US:en'},
#    {'name': 'CoinDesk',
#     'category': 'crypto',
#     'tier': 1,
#     'lang': None,
#     'tags': ['btc', 'eth', 'markets', 'institutional'],
#     'feed_url': 'https://www.coindesk.com/arc/outboundfeeds/rss/'},
#    {'name': 'EIA Reports',
#     'category': 'energy',
#     'tier': 1,
#     'lang': None,
#     'tags': ['eia', 'inventory'],
#     'feed_url': 'https://www.eia.gov/rss/press_room.xml'},
#    {'name': 'Reuters Energy',
#     'category': 'energy',
#     'tier': 1,
#     'lang': None,
#     'tags': ['energy', 'wire'],
#     'feed_url': 'https://news.google.com/rss/search?q=site:reuters.com+(oil+OR+gas+OR+energy)+when:1d&hl=en-US&gl=US&ceid=US:en'},
#    {'name': 'Bloomberg Markets',
#     'category': 'markets',
#     'tier': 1,
#     'lang': None,
#     'tags': ['markets', 'terminal'],
#     'feed_url': 'https://news.google.com/rss/search?q=site:bloomberg.com+markets+when:1d&hl=en-US&gl=US&ceid=US:en'},
#    {'name': 'CNBC',
#     'category': 'markets',
#     'tier': 1,
#     'lang': None,
#     'tags': ['equities', 'macro'],
#     'feed_url': 'https://www.cnbc.com/id/100003114/device/rss/rss.html'},
#    {'name': 'Reuters Markets',
#     'category': 'markets',
#     'tier': 1,
#     'lang': None,
#     'tags': ['markets', 'wire'],
#     'feed_url': 'https://news.google.com/rss/search?q=site:reuters.com+markets+stocks+when:1d&hl=en-US&gl=US&ceid=US:en'},
#    {'name': 'SEC',
#     'category': 'regulation',
#     'tier': 1,
#     'lang': None,
#     'tags': ['sec', 'enforcement', 'etf'],
#     'feed_url': 'https://www.sec.gov/news/pressreleases.rss'}]},
#  'news': {'ok': True,
#   'count': 5,
#   'articles': [{'name': 'Federal Reserve',
#     'title': 'Agencies clarify the capital treatment of tokenized securities',
#     'tier': 1,
#     'category': 'centralbanks',
#     'published_at': '2026-03-05T20:30:00Z',
#     'url': 'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20260305a.htm'},
#    {'name': 'Federal Reserve',
#     'title': 'Federal Reserve Board announces termination of enforcement action with Wells Fargo',
#     'tier': 1,
#     'category': 'centralbanks',
#     'published_at': '2026-03-05T16:00:00Z',
#     'url': 'https://www.federalreserve.gov/newsevents/pressreleases/enforcement20260305a.htm'},
#    {'name': 'Federal Reserve',
#     'title': 'Federal Reserve Board issues enforcement actions with former employee of East Cambridge Savings Bank and former employee of United Bank',
#     'tier': 1,
#     'category': 'centralbanks',
#     'published_at': '2026-03-03T16:00:00Z',
#     'url': 'https://www.federalreserve.gov/newsevents/pressreleases/enforcement20260303a.htm'},
#    {'name': 'Federal Reserve',
#     'title': "Minutes of the Board's discount rate meetings on January 20 and 28, 2026",
#     'tier': 1,
#     'category': 'centralbanks',
#     'published_at': '2026-02-24T19:00:00Z',
#     'url': 'https://www.federalreserve.gov/newsevents/pressreleases/monetary20260224a.htm'},
#    {'name': 'Federal Reserve',
#     'title': 'Federal Reserve Board issues enforcement action with former employee of First Financial Bank',
#     'tier': 1,
#     'category': 'centralbanks',
#     'published_at': '2026-02-24T16:00:00Z',
#     'url': 'https://www.federalreserve.gov/newsevents/pressreleases/enforcement20260224a.htm'}]}}

# %% [markdown]
# ## Tier 1 Sources

# %%
await run_list_sources(tiers=[1], limit=20)
# Out:
# {'ok': True,
#  'count': 10,
#  'sources': [{'name': 'Federal Reserve',
#    'category': 'centralbanks',
#    'tier': 1,
#    'lang': None,
#    'tags': ['rates', 'liquidity', 'fed'],
#    'feed_url': 'https://www.federalreserve.gov/feeds/press_all.xml'},
#   {'name': 'Bloomberg Commodities',
#    'category': 'commodity-news',
#    'tier': 1,
#    'lang': None,
#    'tags': ['commodities', 'wire'],
#    'feed_url': 'https://news.google.com/rss/search?q=site:bloomberg.com+commodities+OR+metals+OR+mining+when:1d&hl=en-US&gl=US&ceid=US:en'},
#   {'name': 'Reuters Commodities',
#    'category': 'commodity-news',
#    'tier': 1,
#    'lang': None,
#    'tags': ['commodities', 'wire'],
#    'feed_url': 'https://news.google.com/rss/search?q=site:reuters.com+commodities+OR+metals+OR+mining+when:1d&hl=en-US&gl=US&ceid=US:en'},
#   {'name': 'CoinDesk',
#    'category': 'crypto',
#    'tier': 1,
#    'lang': None,
#    'tags': ['btc', 'eth', 'markets', 'institutional'],
#    'feed_url': 'https://www.coindesk.com/arc/outboundfeeds/rss/'},
#   {'name': 'EIA Reports',
#    'category': 'energy',
#    'tier': 1,
#    'lang': None,
#    'tags': ['eia', 'inventory'],
#    'feed_url': 'https://www.eia.gov/rss/press_room.xml'},
#   {'name': 'Reuters Energy',
#    'category': 'energy',
#    'tier': 1,
#    'lang': None,
#    'tags': ['energy', 'wire'],
#    'feed_url': 'https://news.google.com/rss/search?q=site:reuters.com+(oil+OR+gas+OR+energy)+when:1d&hl=en-US&gl=US&ceid=US:en'},
#   {'name': 'Bloomberg Markets',
#    'category': 'markets',
#    'tier': 1,
#    'lang': None,
#    'tags': ['markets', 'terminal'],
#    'feed_url': 'https://news.google.com/rss/search?q=site:bloomberg.com+markets+when:1d&hl=en-US&gl=US&ceid=US:en'},
#   {'name': 'CNBC',
#    'category': 'markets',
#    'tier': 1,
#    'lang': None,
#    'tags': ['equities', 'macro'],
#    'feed_url': 'https://www.cnbc.com/id/100003114/device/rss/rss.html'},
#   {'name': 'Reuters Markets',
#    'category': 'markets',
#    'tier': 1,
#    'lang': None,
#    'tags': ['markets', 'wire'],
#    'feed_url': 'https://news.google.com/rss/search?q=site:reuters.com+markets+stocks+when:1d&hl=en-US&gl=US&ceid=US:en'},
#   {'name': 'SEC',
#    'category': 'regulation',
#    'tier': 1,
#    'lang': None,
#    'tags': ['sec', 'enforcement', 'etf'],
#    'feed_url': 'https://www.sec.gov/news/pressreleases.rss'}]}

# %% [markdown]
# ## Central Bank News

# %%
await run_search(categories=["centralbanks"], tiers=[1, 2], timespan="30d", limit=10)
# Out:
# {'ok': True,
#  'count': 10,
#  'articles': [{'name': 'BoJ Watch',
#    'title': 'Tokyo Inflation Slows Below Bank of Japan’s Target But Rate-Hike Path Seems Intact - WSJ',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-07T12:54:19Z',
#    'url': 'https://news.google....?oc=5'},
#   {'name': 'BoJ Watch',
#    'title': 'Tokyo Inflation Slows Below Bank of Japan’s Target But Rate-Hike Path Seems Intact - WSJ',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-07T12:54:19Z',
#    'url': 'https://news.google....?oc=5'},
#   {'name': 'PBoC Watch',
#    'title': 'PBOC continues gold buying streak for 16th consecutive month - Nation Thailand',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-07T11:26:00Z',
#    'url': 'https://news.google.com/rss/articles/CBMiX0FVX3lxTE9aSEdtblF3anhRQWZjTjVUNjdRczBZR2FwUnRNQzgzQVo0bWdkRi1vRHg5S05mWnZ1V0tWaHVVd2tLZ0V4SEFqQUtDbVRJR3BJc3U0bEJUb0k4YkhILVJV?oc=5'},
#   {'name': 'PBoC Watch',
#    'title': 'Long road ahead for China’s consumption pivot, PBOC adviser tells Bloomberg - WHTC',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-07T08:15:07Z',
#    'url': 'https://news.google.com/rss/articles/CBMipAFBVV95cUxPemVKWk5pQ21EbkRDa3VodC1BbElUcG5vUHo5SUxrTWw3V1BTRkxoNzIzd3c5UGlaYUEteWc1RnE5ZXlZNlo0MXZfZk52Nk1mRnVVQk9PVGNwUDUyZEUtcnZqc29TbVhxVU1tT09kQml5NXlFM3QwMWNhaEhVQXc3c05KVXhleG9aRU5TNkpPb2x6dnFOSG1NRTNaU1ZYT1ZBT1lSNA?oc=5'},
#   {'name': 'BoE Watch',
#    'title': '70% of banks have cut interest rates this year – and there’s more to come - MSN',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-07T03:58:55Z',
#    'url': 'https://news.google....?oc=5'},
#   {'name': 'PBoC Watch',
#    'title': 'China’s PBOC Extends Gold Buying as Middle East Tension Simmers - Bloomberg.com',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-07T02:44:06Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'ECB Watch',
#    'title': 'The European Central Bank warns of inflation risks as the war in the Middle East escalates - المتداول العربي',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-06T18:37:10Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'BoE Watch',
#    'title': 'Where Next for UK Interest Rates and Inflation Amid Iran War? - Morningstar Canada',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-06T17:16:44Z',
#    'url': 'https://news.google.com/rss/articles/CBMingFBVV95cUxPWnl1VURkMFhqU05XWWRSakQ1UEVfX01LLW9TZG82QVl6MkZtZlBfRFVSYWI5SkdFZUdreGI1MTNmczZPdlFUY04xRVQ4VG1GSlcyQUloaWliN1BCelF5cXpsekl1WDdXRGRkLUd3TXg3bjNFaVNlTUFNZFkzTjJvZmdnRDRkRVUzQmg3YVhFakJmT0d4VlE5WVBVMGlHUQ?oc=5'},
#   {'name': 'BoE Watch',
#    'title': "Bank of England scrutinizes lenders' ties to collapsed mortgage provider MFS, FT reports - Reuters",
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-06T17:02:06Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'BoJ Watch',
#    'title': 'GBP/JPY Stability: Markets Reassess BoE Rate Cuts and Delay BoJ Hikes Amid Economic Shifts - Bitcoin world',
#    'tier': 2,
#    'category': 'centralbanks',
#    'published_at': '2026-03-06T16:01:36Z',
#    'url': 'https://news.google.com/rss/articles/CBMia0FVX3lxTFBpMzd2YzFpTkYzVWt0U1kyN1lIbXRhSnJEZnhxaGVKeWozTUdrUmh0dnZsYW5OenNzVzhmM0t0aW1VUlUtcURhRVBxNnFVQUZFTFBfLTFUeXEtbVlwYnNrd0RuZVR6Mm5pdnRj?oc=5'}]}

# %% [markdown]
# ## Specific Sources

# %%
await run_search(sources=["Federal Reserve", "Reuters Markets"], timespan="30d", limit=10)
# Out:
# {'ok': True,
#  'count': 10,
#  'articles': [{'name': 'Reuters Markets',
#    'title': 'Indian Oil Corp books some oil cargoes from Red Sea, source says - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-07T12:08:12Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': 'Iran war threatens a prolonged hit to global energy markets - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-07T11:14:35Z',
#    'url': 'https://news.google.com/rss/articles/CBMiqgFBVV95cUxNb05tQUczS3pRVDllRmdvTE9yZ0pmT2tFM1RYQTZyYm1DanAwVjJROWJ3UXV0NEhoZk5qeEN2b2lfOTIzZ1Q2M2szR2RVdl9RWVNhczlKT0RzNlVLWjlrdms3aDJWZk42cU5TNmRGUHQ0bUlHZFFabEU3ZFQyWTY0cU50alhrRUc0dzBOX20wYUpoN0xPMDVUVUhJcTNTNms5WGJZU2w2MGVSdw?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': "Iran's future: Listen to our journalists in the Middle East - Reuters",
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-07T10:36:32Z',
#    'url': 'https://news.google.com/rss/articles/CBMilwFBVV95cUxPcXZkQ1NsYkhwVlZRc0NRZTBIRlVsVl94c1VQTHJndU1kY053bjVfaGdES0hRUnRDZjkwQ045WTR4andZeEdkM2VLY1RybVUxWFIzMUNpamMxV2dkQ0t0WDB6WG0zS0ZyV0JtOS1LaXRZNjlnaF9jU2lNU2VNcWotWlQxZWU1WEk1VXZobkJJZDFLMkpBdFFN?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': 'As war spreads, airline pilots contend with drones, missiles - and stress - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-07T01:25:50Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': 'Novo and Hims to sell obesity drugs together as feud ends, Bloomberg News reports - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-07T01:04:00Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': 'Pakistan raises retail fuel prices by about 20% due to Middle East tension - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-06T23:25:39Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': 'Vertiv, Lumentum, Coherent, EchoStar set to join S&P 500 - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-06T23:16:59Z',
#    'url': 'https://news.google.com/rss/articles/CBMirAFBVV95cUxQQkNheTRybnUyZ29uMGR6cWFRcjNKaWlnQVpyeHhnOF9sNTdjOHdGdjNfOWgzY01QdGNQc0s1eUF4MTd3czQweTAtT0xyS1JIZ3J1ODdEdnV1dm1YeWV4MWdnUWxxbHMyWGo4ODFSM2t4ckVJSXRaMTN1S0c1Tm9UeHo4NHBiWjZEcUNvZk9WRmktUkVlNTFEN1MyYjgzbF9YbEREV0FHeHNnR1VX?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': 'Former US trade chief Lighthizer resigns from Trump Media board - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-06T22:40:43Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': 'Goldman Sachs warns oil may surge above $100/bbl if Hormuz flows don’t recover - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-06T22:28:29Z',
#    'url': 'https://news.google.?oc=5'},
#   {'name': 'Reuters Markets',
#    'title': 'Boeing CEO took home $9.4 million in 2025 - Reuters',
#    'tier': 1,
#    'category': 'markets',
#    'published_at': '2026-03-06T21:55:48Z',
#    'url': 'https://news.google.?oc=5'}]}

# %% [markdown]
# ## Lower-Tier Market Sources

# %%
await run_search(categories=["markets"], tiers=[2, 3], timespan="14d", limit=10, sort="TierAsc")
# Out:
# {'ok': True,
#  'count': 10,
#  'articles': [{'name': 'Yahoo Finance',
#    'title': 'Nvidia Stock Has Fallen Almost 5% This Year. Is Now a Good Time to Buy?',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T17:07:00Z',
#    'url': 'https://finance.yahoo.com/news/nvidia-stock-fallen-almost-5-170700578.html'},
#   {'name': 'Seeking Alpha',
#    'title': 'Real estate stocks slump as Iran conflict pushes Treasury yields up, muddles path to rate cuts',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T17:00:38Z',
#    'url': 'https://seekingalpha.com/news/4562033-real-estate-stocks-slump-as-iran-conflict-pushes-treasury-yields-up-muddles-path-to-rate-cuts?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news'},
#   {'name': 'Yahoo Finance',
#    'title': 'What Drove Polestar Stock Down 29% This Week?',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T17:00:00Z',
#    'url': 'https://finance.yahoo.com/news/drove-polestar-stock-down-29-170000994.html'},
#   {'name': 'Yahoo Finance',
#    'title': 'The Trade Desk vs. AppLovin: Which AI-Powered Adtech Stock Is the Better Buy?',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T16:56:00Z',
#    'url': 'https://finance.yahoo.com/news/trade-desk-vs-applovin-ai-165600858.html'},
#   {'name': 'Yahoo Finance',
#    'title': "This Glorious Growth Stock Is Down 60%. Here's Why You Should Buy It Hand Over Fist.",
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T16:50:00Z',
#    'url': 'https://finance.yahoo.com/news/glorious-growth-stock-down-60-165000093.html'},
#   {'name': 'Yahoo Finance',
#    'title': 'Why Ford Stock Sank This Week',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T16:49:35Z',
#    'url': 'https://finance.yahoo.com/news/why-ford-stock-sank-week-164935011.html'},
#   {'name': 'Yahoo Finance',
#    'title': 'Is Oracle’s Massive $500 Billion Stargate Project in Trouble?',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T16:46:57Z',
#    'url': 'https://finance.yahoo.com/news/oracle-massive-500-billion-stargate-164657348.html'},
#   {'name': 'Seeking Alpha',
#    'title': 'Mid-cap financial stocks ranked by quant ratings after earnings season',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T16:45:45Z',
#    'url': 'https://seekingalpha.com/news/4561865-mid-cap-financial-stocks-ranked-by-quant-ratings-after-earnings-season?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news'},
#   {'name': 'Yahoo Finance',
#    'title': 'The 2026 Social Security COLA Is Already Failing Retirees',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T16:37:57Z',
#    'url': 'https://finance.yahoo.com/news/2026-social-security-cola-already-163757814.html'},
#   {'name': 'Seeking Alpha',
#    'title': 'Roche continues to expect tariff impact on diagnostics despite U.S. deal',
#    'tier': 2,
#    'category': 'markets',
#    'published_at': '2026-03-07T16:37:01Z',
#    'url': 'https://seekingalpha.com/news/4562082-roche-continues-expect-tariff-impact-diagnostics?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news'}]}
